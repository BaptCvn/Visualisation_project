# %%
import geopandas as gpd
import pandas as pd
import altair as alt
import json

# %%
# 1. LOAD & PREP THE NAME DATA
csv_path = "Names_hints/dpt2020.csv"
df = (
    pd.read_csv(csv_path, sep=";")
      .query("preusuel != '_PRENOMS_RARES'")
      .astype({"dpt": str})                         # keep leading zeros (e.g. '01')
)

# aggregate across sexes
df_agg = (
    df.groupby(["annais", "dpt", "preusuel"], as_index=False)["nombre"]
      .sum()
)

# total births per (year, dept) → percentages
tot = (
    df_agg.groupby(["annais", "dpt"], as_index=False)["nombre"]
          .sum()
          .rename(columns={"nombre": "total"})
)
df_agg = df_agg.merge(tot, on=["annais", "dpt"])
df_agg["pct"] = df_agg["nombre"] / df_agg["total"] * 100

# keep top-5 names per (year, dept) and pivot wide
def top5(group):
    top = group.nlargest(5, "nombre")
    top["rank"] = range(1, len(top) + 1)
    return top

df_top5 = (
    df_agg.groupby(["annais", "dpt"], group_keys=False)
          .apply(top5)
)

wide = (
    df_top5
      .pivot(index=["annais", "dpt"], columns="rank", values=["preusuel", "pct"])
      .reset_index()
)

# flatten MultiIndex columns → annais, dpt, top1_name, top1_pct, … top5_pct
wide.columns = (
    ["annais", "dpt"] +
    [f"top{r}_{kind}" for kind in ("name", "pct") for r in range(1, 6)]
)
df_wide_filtered = wide                         # table used in transform_lookup

# 2. LOAD DEPARTMENT GEOMETRY
geo_path = "Names_hints/departements-version-simplifiee.geojson"
with open(geo_path) as f:
    fr_geojson = json.load(f)                   # GeoJSON stays as dict for Altair

# 3. BUILD THE ALTAIR CHOROPLETH WITH A YEAR SLIDER
# Filter out 'XXXX' values before calculating year range
year_data = wide[wide.annais != 'XXXX']
year_min, year_max = int(year_data.annais.min()), int(year_data.annais.max())
year_sel = alt.param(
    name="Année",
    value=year_max,
    bind=alt.binding_range(min=year_min, max=year_max, step=1, name="Année")
)
# Out:
# /tmp/ipykernel_38262/3485135194.py:32: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(top5)

# %%
# Filter out 'XXXX' values before calculating year range
year_data = wide[wide.annais != 'XXXX']
year_min, year_max = int(year_data.annais.min()), int(year_data.annais.max())
year_sel = alt.param(
    name="year",  # Changed from "Année" to "year"
    value=year_max,
    bind=alt.binding_range(min=year_min, max=year_max, step=1, name="Année")  # Display name can still use special characters
)

chart = (
    alt.Chart(alt.InlineData(values=fr_geojson, format=alt.DataFormat(type="json", property="features")))
       .mark_geoshape(stroke="black", strokeWidth=0.2)
       .encode(
            color=alt.Color(
                "top1_name:N",
                title="Prénom le + donné",
                scale=alt.Scale(scheme="category20")
            ),
            tooltip=[
                alt.Tooltip("top1_name:N", title="1er prénom"),
                alt.Tooltip("top1_pct:Q",  title="%"),
                alt.Tooltip("top2_name:N", title="2ᵉ prénom"),
                alt.Tooltip("top2_pct:Q",  title="%"),
                alt.Tooltip("top3_name:N", title="3ᵉ prénom"),
                alt.Tooltip("top3_pct:Q",  title="%"),
                alt.Tooltip("top4_name:N", title="4ᵉ prénom"),
                alt.Tooltip("top4_pct:Q",  title="%"),
                alt.Tooltip("top5_name:N", title="5ᵉ prénom"),
                alt.Tooltip("top5_pct:Q",  title="%"),
            ]
       )
       .transform_lookup(
            lookup="properties.code",
            from_=alt.LookupData(
                df_wide_filtered,
                key="dpt",
                fields=list(df_wide_filtered.columns)
            )
       )
       .add_params(year_sel)
       .transform_filter(year_sel)
       .project("mercator")
       .properties(width=650, height=800)
)
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# Cell In[3], line 34
#       3 year_min, year_max = int(year_data.annais.min()), int(year_data.annais.max())
#       4 year_sel = alt.param(
#       5     name="year",  # Changed from "Année" to "year"
#       6     value=year_max,
#       7     bind=alt.binding_range(min=year_min, max=year_max, step=1, name="Année")  # Display name can still use special characters
#       8 )
#      10 chart = (
#      11     alt.Chart(alt.InlineData(values=fr_geojson, format=alt.DataFormat(type="json", property="features")))
#      12        .mark_geoshape(stroke="black", strokeWidth=0.2)
#      13        .encode(
#      14             color=alt.Color(
#      15                 "top1_name:N",
#      16                 title="Prénom le + donné",
#      17                 scale=alt.Scale(scheme="category20")
#      18             ),
#      19             tooltip=[
#      20                 alt.Tooltip("top1_name:N", title="1er prénom"),
#      21                 alt.Tooltip("top1_pct:Q",  title="%"),
#      22                 alt.Tooltip("top2_name:N", title="2ᵉ prénom"),
#      23                 alt.Tooltip("top2_pct:Q",  title="%"),
#      24                 alt.Tooltip("top3_name:N", title="3ᵉ prénom"),
#      25                 alt.Tooltip("top3_pct:Q",  title="%"),
#      26                 alt.Tooltip("top4_name:N", title="4ᵉ prénom"),
#      27                 alt.Tooltip("top4_pct:Q",  title="%"),
#      28                 alt.Tooltip("top5_name:N", title="5ᵉ prénom"),
#      29                 alt.Tooltip("top5_pct:Q",  title="%"),
#      30             ]
#      31        )
#      32        .transform_lookup(
#      33             lookup="properties.code",
# ---> 34             from_=alt.LookupData(
#      35                 df_wide_filtered,
#      36                 key="dpt",
#      37                 fields=list(df_wide_filtered.columns)
#      38             )
#      39        )
#      40        .add_params(year_sel)
#      41        .transform_filter(year_sel)
#      42        .project("mercator")
#      43        .properties(width=650, height=800)
#      44 )
#
# File ~/Documents/Code_Telecom/Visualisation_project/.env_data_viz/lib/python3.12/site-packages/altair/vegalite/v5/api.py:310, in LookupData.__init__(self, *args, **kwargs)
#     308 @utils.use_signature(core.LookupData)
#     309 def __init__(self, *args: Any, **kwargs: Any) -> None:
# --> 310     super().__init__(*args, **kwargs)
#
# File ~/Documents/Code_Telecom/Visualisation_project/.env_data_viz/lib/python3.12/site-packages/altair/vegalite/v5/schema/core.py:11070, in LookupData.__init__(self, data, key, fields, **kwds)
#   11063 def __init__(
#   11064     self,
#   11065     data: Optional[SchemaBase | Map] = Undefined,
#    (...)  11068     **kwds,
#   11069 ):
# > 11070     super().__init__(data=data, key=key, fields=fields, **kwds)
#
# File ~/Documents/Code_Telecom/Visualisation_project/.env_data_viz/lib/python3.12/site-packages/altair/utils/schemapi.py:1043, in SchemaBase.__init__(self, *args, **kwds)
#    1040 object.__setattr__(self, "_kwds", kwds)
#    1042 if DEBUG_MODE and self._class_is_valid_at_instantiation:
# -> 1043     self.to_dict(validate=True)
#
# File ~/Documents/Code_Telecom/Visualisation_project/.env_data_viz/lib/python3.12/site-packages/altair/vegalite/v5/api.py:315, in LookupData.to_dict(self, *args, **kwargs)
#     313 """Convert the chart to a dictionary suitable for JSON export."""
#     314 copy = self.copy(deep=False)
# --> 315 copy.data = _prepare_data(copy.data, kwargs.get("context"))
#     316 return super(LookupData, copy).to_dict(*args, **kwargs)
#
# File ~/Documents/Code_Telecom/Visualisation_project/.env_data_viz/lib/python3.12/site-packages/altair/vegalite/v5/api.py:283, in _prepare_data(data, context)
#     281 elif not isinstance(data, dict) and _is_data_type(data):
#     282     if func := data_transformers.get():
# --> 283         data = func(nw.to_native(data, pass_through=True))
#     285 # convert string input to a URLData
#     286 elif isinstance(data, str):
#
# File ~/Documents/Code_Telecom/Visualisation_project/.env_data_viz/lib/python3.12/site-packages/altair/vegalite/data.py:42, in default_data_transformer(data, max_rows)
#      39     return pipe
#      41 else:
# ---> 42     return to_values(limit_rows(data, max_rows=max_rows))
#
# File ~/Documents/Code_Telecom/Visualisation_project/.env_data_viz/lib/python3.12/site-packages/altair/utils/data.py:165, in limit_rows(data, max_rows)
#     162     values = data
#     164 if max_rows is not None and len(values) > max_rows:
# --> 165     raise_max_rows_error()
#     167 return data
#
# File ~/Documents/Code_Telecom/Visualisation_project/.env_data_viz/lib/python3.12/site-packages/altair/utils/data.py:148, in limit_rows.<locals>.raise_max_rows_error()
#     135 def raise_max_rows_error():
#     136     msg = (
#     137         "The number of rows in your dataset is greater "
#     138         f"than the maximum allowed ({max_rows}).\n\n"
#    (...)    146         "on how to plot large datasets."
#     147     )
# --> 148     raise MaxRowsError(msg)
#
# MaxRowsError: The number of rows in your dataset is greater than the maximum allowed (5000).
#
# Try enabling the VegaFusion data transformer which raises this limit by pre-evaluating data
# transformations in Python.
#     >> import altair as alt
#     >> alt.data_transformers.enable("vegafusion")
#
# Or, see https://altair-viz.github.io/user_guide/large_datasets.html for additional information
# on how to plot large datasets.

# %%
chart
# Out:
# alt.Chart(...)

# %%
import geopandas as gpd
import pandas as pd
import altair as alt
import json

# ────────────────────────────────────────────────────────────
# 1. LOAD & PREP THE NAME DATA
# ────────────────────────────────────────────────────────────
csv_path = "Names_hints/dpt2020.csv"
df = (
    pd.read_csv(csv_path, sep=";")
      .query("preusuel != '_PRENOMS_RARES'")
      .astype({"dpt": str})                       # keep leading zeros (e.g. '01')
)

# aggregate across sexes
df_agg = (
    df.groupby(["annais", "dpt", "preusuel"], as_index=False)["nombre"]
      .sum()
)

# total births per (year, dept) → percentages
tot = (
    df_agg.groupby(["annais", "dpt"], as_index=False)["nombre"]
          .sum()
          .rename(columns={"nombre": "total"})
)
df_agg = df_agg.merge(tot, on=["annais", "dpt"])
df_agg["pct"] = df_agg["nombre"] / df_agg["total"] * 100

# keep top-5 names per (year, dept) and pivot to wide format
def top5(group):
    top = group.nlargest(5, "nombre").copy()
    top["rank"] = range(1, len(top) + 1)
    return top

df_top5 = (
    df_agg.groupby(["annais", "dpt"], group_keys=False)
          .apply(top5, include_groups=False)
)

wide = (
    df_top5
      .pivot(index=["annais", "dpt"], columns="rank", values=["preusuel", "pct"])
      .reset_index()
)

# flatten MultiIndex columns → annais, dpt, top1_name, top1_pct, …, top5_pct
wide.columns = ["annais", "dpt"] + [
    f"top{rank}_{'name' if col0 == 'preusuel' else 'pct'}"
    for col0, rank in wide.columns[2:]
]
df_wide = wide[wide["annais"] != "XXXX"]          # drop ambiguous year rows

# ────────────────────────────────────────────────────────────
# 2. LOAD DEPARTMENT GEOMETRY
# ────────────────────────────────────────────────────────────
geo_path = "Names_hints/departements-version-simplifiee.geojson"
with open(geo_path) as f:
    fr_geojson = json.load(f)                     # dict → Altair InlineData

# ────────────────────────────────────────────────────────────
# 3. BUILD THE ALTAIR CHOROPLETH WITH A YEAR SLIDER
# ────────────────────────────────────────────────────────────
year_min, year_max = int(df_wide.annais.min()), int(df_wide.annais.max())

year_sel = alt.param(
    name="year",
    value=year_max,
    bind=alt.binding_range(min=year_min, max=year_max, step=1, name="Année")
)

chart = (
    alt.Chart(
        alt.InlineData(values=fr_geojson, format=alt.DataFormat(type="json", property="features"))
    )
    .mark_geoshape(stroke="black", strokeWidth=0.2)
    .encode(
        color=alt.Color(
            "top1_name:N",
            title="Prénom le + donné",
            scale=alt.Scale(scheme="category20")
        ),
        tooltip=[
            alt.Tooltip("top1_name:N", title="1ᵉʳ prénom"),
            alt.Tooltip("top1_pct:Q",  title="%"),
            alt.Tooltip("top2_name:N", title="2ᵉ prénom"),
            alt.Tooltip("top2_pct:Q",  title="%"),
            alt.Tooltip("top3_name:N", title="3ᵉ prénom"),
            alt.Tooltip("top3_pct:Q",  title="%"),
            alt.Tooltip("top4_name:N", title="4ᵉ prénom"),
            alt.Tooltip("top4_pct:Q",  title="%"),
            alt.Tooltip("top5_name:N", title="5ᵉ prénom"),
            alt.Tooltip("top5_pct:Q",  title="%"),
        ]
    )
    .transform_lookup(
        lookup="properties.code",                 # dept code in GeoJSON
        from_=alt.LookupData(
            df_wide,
            key="dpt",
            fields=list(df_wide.columns)          # includes annais + topN cols
        )
    )
    .add_params(year_sel)
    .transform_filter(alt.datum.annais == year_sel)
    .properties(width=650, height=800)
)

chart
# Out:
# /tmp/ipykernel_26533/3164595093.py:39: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(top5)
# /tmp/ipykernel_26533/3164595093.py:105: AltairDeprecationWarning:
# Deprecated since `altair=5.0.0`. Use add_params instead.
#   .add_selection(year_sel)
# alt.Chart(...)
